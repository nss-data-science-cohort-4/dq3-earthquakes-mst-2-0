# %%
# import packages

# import clevercsv as csv
import re
from datetime import datetime
import time
import scipy.stats as stats
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.io as pio
import plotly.express as px
import pandas_profiling as pdp
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
import csv
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from io import StringIO
# %matplotlib inline

# %%
test = pd.read_csv('cleaned_earthquake_df')

# %%
tn_earthquake = pd.read_csv('cleaned_earthquake_data')

# %% [markdown]
# 1. How many earthquakes are in the dataset?

# %%
tn_earthquake.shape
# Out:
# (4755, 26)

# %% [markdown]
# # Answer
# 4752

# %%
df = px.data.election()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   district     58 non-null     object
#  1   Coderre      58 non-null     int64
#  2   Bergeron     58 non-null     int64
#  3   Joly         58 non-null     int64
#  4   total        58 non-null     int64
#  5   winner       58 non-null     object
#  6   result       58 non-null     object
#  7   district_id  58 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 3.8+ KB

# %%
df.tail()
# Out:
#               district  Coderre  Bergeron  Joly  total    winner     result  \
# 53   82-Ovide-Clermont     6229       780  1051   8060   Coderre   majority
# 54      91-Claude-Ryan      996       643   423   2062   Coderre  plurality
# 55  92-Joseph-Beaubien      540       833   592   1965  Bergeron  plurality
# 56  93-Robert-Bourassa      446       465   419   1330  Bergeron  plurality
# 57     94-Jeanne-Sauvé      491       698   489   1678  Bergeron  plurality
#
#     district_id
# 53           82
# 54           91
# 55           92
# 56           93
# 57           94

# %%
tn_earthquake['iso_alpha'] = 'US-TN'

# %%
tn_earthquake.head()
# Out:
#    Unnamed: 0      time   latitude  longitude  depth   mag magType   nst  \
# 0          15  00:54:37  36.141500 -89.457667  11.47  1.25      md  16.0
# 1          16  14:41:42  36.168833 -89.463333  11.87  2.06      md  36.0
# 2          17  11:33:20  36.345000 -89.516667   5.33  1.33      md  15.0
# 3          18  05:37:13  36.297167 -89.535667  10.26  1.45      md  18.0
# 4          19  04:16:27  36.295833 -89.534167   9.91  1.39      md  21.0
#
#     gap     dmin  ...  depthError magError magNst    status locationSource  \
# 0  58.0  0.04641  ...        1.25    0.090    9.0  reviewed             nm
# 1  44.0  0.03136  ...        0.33    0.096   30.0  reviewed             nm
# 2  75.0  0.01536  ...        0.57    0.070   11.0  reviewed             nm
# 3  49.0  0.03705  ...        0.71    0.028   12.0  reviewed             nm
# 4  49.0  0.03885  ...        0.37    0.091   15.0  reviewed             nm
#
#   magSource      state        date  year  iso_alpha
# ...

# %%
geojson = px.data.election_geojson()

fig = px.choropleth_mapbox(tn_earthquake, geojson=geojson, color="mag",
                           locations="state", featureidkey="properties.district",
                           center={"lat": 34, "lon": -90},
                           mapbox_style="carto-positron", zoom=5)
fig.show()
# Out:
# <div>                            <div id="b34fbbe0-087f-4950-8b3d-8fec3698d715" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b34fbbe0-087f-4950-8b3d-8fec3698d715")) {                    Plotly.newPlot(                        "b34fbbe0-087f-4950-8b3d-8fec3698d715",                        [{"coloraxis": "coloraxis", "featureidkey": "properties.district", "geojson": {"features": [{"geometry": {"coordinates": [[[[-73.6363215300962, 45.5759177646435], [-73.6362833815582, 45.5758266113331], [-73.6446417578686, 45.5658132919643], [-73.6453511352974, 45.5647725775888], [-73.648867564748, 45.5586898267402], [-73.6513170845065, 45.5545659435652], [-73.6515658357324, 45.5554439857955], [-73.6660837831645, 45.5596724837829], [-73.6706609041685, 45.5610978251
# ...

# %%
fig = px.choropleth(tn_earthquake,lat=tn_earthquake.latitude, lon=tn_earthquake.longitude, color="mag", hover_name="place", animation_frame="year", range_color=[0,5])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-c04e7900864c> in <module>
# ----> 1 fig = px.choropleth(tn_earthquake,lat=tn_earthquake.latitude, lon=tn_earthquake.longitude, color="mag", hover_name="place", animation_frame="year", range_color=[0,5])
#       2 fig.show()
#
# ~\anaconda3\lib\site-packages\plotly\express\_chart_types.py in choropleth(data_frame, lat, lon, locations, locationmode, geojson, featureidkey, color, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, projection, scope, center, title, template, width, height)
#     965     colored region mark on a map.
#     966     """
# --> 967     return make_figure(
#     968         args=locals(),
#     969         constructor=go.Choropleth,
#
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Densitymapbox(lat=tn_earthquake.latitude, lon=tn_earthquake.longitude, z=tn_earthquake.mag, radius=10))
fig.update_layout(mapbox_style="stamen-terrain", mapbox_center_lon=180)
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div>                            <div id="24c88553-8c4f-4d5c-b627-be068c1a77ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24c88553-8c4f-4d5c-b627-be068c1a77ed")) {                    Plotly.newPlot(                        "24c88553-8c4f-4d5c-b627-be068c1a77ed",                        [{"lat": [36.1415, 36.1688333, 36.345, 36.2971667, 36.2958333, 36.2091667, 36.27616670000001, 36.1018333, 36.2225, 36.2406667, 36.246, 35.57966670000001, 36.348, 36.344, 36.225, 36.1493333, 36.2441667, 36.2441667, 36.2436667, 36.2451667, 36.244, 36.2981667, 36.3311667, 36.041, 35.7063333, 36.2783333, 36.2831667, 36.266, 36.2518333, 35.70016670000001, 35.5391667, 35.313, 36.3205, 36.2363333, 36.3695, 36.2555, 36.2655, 36.175, 35.1968333, 36.266, 36.4093333, 36.242,
# ...

# %% [markdown]
# Which region of Tennessee seems to be the most prone to earthquakes?
# # Answer
# East TN

# %% [markdown]
#  Which is the least prone?
#  # Answer
#  middle TN

# %%
tn_earthquake.head()
# Out:
#    Unnamed: 0      time   latitude  longitude  depth   mag magType   nst  \
# 0          15  00:54:37  36.141500 -89.457667  11.47  1.25      md  16.0
# 1          16  14:41:42  36.168833 -89.463333  11.87  2.06      md  36.0
# 2          17  11:33:20  36.345000 -89.516667   5.33  1.33      md  15.0
# 3          18  05:37:13  36.297167 -89.535667  10.26  1.45      md  18.0
# 4          19  04:16:27  36.295833 -89.534167   9.91  1.39      md  21.0
#
#     gap     dmin  ...  horizontalError depthError magError magNst    status  \
# 0  58.0  0.04641  ...             0.48       1.25    0.090    9.0  reviewed
# 1  44.0  0.03136  ...             0.24       0.33    0.096   30.0  reviewed
# 2  75.0  0.01536  ...             0.29       0.57    0.070   11.0  reviewed
# 3  49.0  0.03705  ...             0.41       0.71    0.028   12.0  reviewed
# 4  49.0  0.03885  ...             0.19       0.37    0.091   15.0  reviewed
#
#   locationSource  magSource      state        date  year
# ...

# %%
test.head()
# Out:
#    Unnamed: 0      time   latitude  longitude  depth   mag magType   nst  \
# 0          15  00:54:37  36.141500 -89.457667  11.47  1.25      md  16.0
# 1          16  14:41:42  36.168833 -89.463333  11.87  2.06      md  36.0
# 2          17  11:33:20  36.345000 -89.516667   5.33  1.33      md  15.0
# 3          18  05:37:13  36.297167 -89.535667  10.26  1.45      md  18.0
# 4          19  04:16:27  36.295833 -89.534167   9.91  1.39      md  21.0
#
#     gap     dmin  ...        type horizontalError depthError magError magNst  \
# 0  58.0  0.04641  ...  earthquake            0.48       1.25    0.090    9.0
# 1  44.0  0.03136  ...  earthquake            0.24       0.33    0.096   30.0
# 2  75.0  0.01536  ...  earthquake            0.29       0.57    0.070   11.0
# 3  49.0  0.03705  ...  earthquake            0.41       0.71    0.028   12.0
# 4  49.0  0.03885  ...  earthquake            0.19       0.37    0.091   15.0
#
#      status  locationSource  magSource      state        date
# ...

# %%
# time line
fig = px.scatter(tn_earthquake, x= 'mag', y='year', color="state")
fig.show()
# Out:
# <div>                            <div id="32d20bd8-a0e6-422e-8dcb-ea79418c0c38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32d20bd8-a0e6-422e-8dcb-ea79418c0c38")) {                    Plotly.newPlot(                        "32d20bd8-a0e6-422e-8dcb-ea79418c0c38",                        [{"hovertemplate": "state=Tennessee<br>mag=%{x}<br>year=%{y}<extra></extra>", "legendgroup": "Tennessee", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Tennessee", "showlegend": true, "type": "scattergl", "x": [1.25, 2.06, 1.33, 1.45, 1.39, 1.13, 1.36, 2.3, 1.26, 1.38, 1.25, 2.31, 0.97, 1.96, 1.26, 1.31, 1.36, 2.47, 2.1, 2.26, 1.6, 1.64, 1.73, 2.03, 2.47, 1.78, 1.73, 2.4, 1.36, 1.98, 2.06, 1.99, 1.15, 2.44, 1.27, 1.36, 1.27, 1.28,
# ...

# %%
fig = px.scatter(tn_earthquake, x= 'mag', y='year', color="state")
fig.show()

# %% [markdown]
# 2. Do the magnitudes of earthquakes seem to follow the distribution described by Nate Silver. That is, one higher magnitude is ten times less likely to occur?
