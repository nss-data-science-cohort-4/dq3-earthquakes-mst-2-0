# %%
import requests
import pandas as pd
from io import StringIO
import json 
import csv 
from shapely.geometry import Point, Polygon
import geopandas as gpd

# %%
# capture data within the tn boarders with longitude and latitude and convert to csv and start the time from 1900 to now
url = 'https://opendata.arcgis.com/datasets/592082987bd5456baab74d70f1bf5d90_0.geojson'

# %%
r = requests.get(url)

# %%
tn_counties = gpd.read_file(url)

# %%
tn_counties.head()
# Out:
#    FID  COUNTYNS  GEOID         NAMELSAD CLASSFP FUNCSTAT       ALAND  \
# 0    1  01639722  47001  Anderson County      H1        A   873246897
# 1    2  01639723  47003   Bedford County      H1        A  1226717421
# 2    3  01639724  47005    Benton County      H1        A  1021240555
# 3    4  01639725  47007   Bledsoe County      H1        A  1052635818
# 4    5  01639726  47009    Blount County      H1        A  1447032438
#
#       AWATER     INTPTLAT     INTPTLON  OBJECTID  Population   Shape__Area  \
# 0   19770493  +36.1167307  -84.1954177      2429       75430  1.371349e+09
# 1    2983130  +35.5136604  -86.4582939      2430       45986  1.860078e+09
# 2  108591318  +36.0692530  -88.0712118      2431       16261  1.732893e+09
# 3     838360  +35.5936683  -85.2059790      2432       13686  1.596774e+09
# 4   20308084  +35.6881849  -83.9229731      2433      125188  2.229352e+09
#
#    Shape__Length                                           geometry
# 0  228490.245321  POLYGON ((-84.33465 36.03021, -84.33470 36.030...
# 1  230137.077697  POLYGON ((-86.63521 35.57742, -86.63569 35.577...
# 2  247138.267705  POLYGON ((-88.13691 36.20954, -88.13695 36.209...
# 3  214142.109472  POLYGON ((-85.22651 35.76643, -85.22644 35.766...
# 4  276030.358407  POLYGON ((-84.14252 35.79696, -84.14158 35.797...

# %%
tn_counties['geometry'].plot(figsize = (15,10))
# Out:
# <AxesSubplot:>
