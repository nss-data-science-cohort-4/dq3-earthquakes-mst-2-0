# %%
import requests
import pandas as pd
from io import StringIO
import json 
import csv

# %%
url = 'https://earthquake.usgs.gov/fdsnws/event/1/query?format=csv&minlatitude=35&maxlatitude=37&minlongitude=-86&maxlongitude=-84&starttime=1900-01-01&endtime=2020-10-17'

# %%
r = requests.get(url)

# %%
print(r.text[:1000])
# Out:
# time,latitude,longitude,depth,mag,magType,nst,gap,dmin,rms,net,id,updated,place,type,horizontalError,depthError,magError,magNst,status,locationSource,magSource
# 2020-09-05T03:41:09.170Z,35.7001667,-84.3481667,14.83,1.98,md,16,81,0.1258,0.11,se,se60328026,2020-10-14T23:10:43.040Z,"Tennessee",earthquake,0.27,0.58,0.195,13,reviewed,se,se
# 2020-09-03T15:24:15.960Z,35.5391667,-84.4621667,9.98,2.06,md,17,48,0.1015,0.16,se,se60327896,2020-09-03T16:50:59.170Z,"6 km S of Sweetwater, Tennessee",earthquake,0.28,0.56,0.04,10,reviewed,se,se
# 2020-08-31T17:20:32.820Z,35.313,-84.2223333,10.74,1.99,md,18,84,0.1907,0.16,se,se60327581,2020-09-01T07:02:39.565Z,"8 km SE of Tellico Plains, Tennessee",earthquake,0.3,1.07,0.074,13,reviewed,se,se
# 2020-08-23T03:56:44.490Z,35.1968333,-85.1328333,0.11,1.2,ml,15,53,0.1467,0.25,se,se60112823,2020-09-28T21:09:39.040Z,"1 km SSW of Lakesite, Tennessee",earthquake,0.48,3.66,,14,reviewed,se,se
# ...

# %%
tn_quake_df = pd.read_csv(StringIO(r.text))
tn_quake_df.head(50)
# Out:
#                         time   latitude  longitude  depth   mag magType   nst  \
# 0   2020-09-05T03:41:09.170Z  35.700167 -84.348167  14.83  1.98      md  16.0
# 1   2020-09-03T15:24:15.960Z  35.539167 -84.462167   9.98  2.06      md  17.0
# 2   2020-08-31T17:20:32.820Z  35.313000 -84.222333  10.74  1.99      md  18.0
# 3   2020-08-23T03:56:44.490Z  35.196833 -85.132833   0.11  1.20      ml  15.0
# 4   2020-07-27T17:22:50.950Z  35.245167 -84.646167  15.73  2.44      md  20.0
# 5   2020-07-26T07:39:09.650Z  35.568167 -84.267667   1.85  1.95      md  10.0
# 6   2020-07-24T03:52:51.880Z  35.675500 -84.301000  10.90  1.54      md   9.0
# 7   2020-07-16T01:25:28.250Z  35.537333 -84.318000  18.22  1.13      md   5.0
# 8   2020-07-14T14:41:19.580Z  35.502833 -84.166000  10.92  2.00      md   9.0
# 9   2020-07-04T03:13:46.770Z  35.485833 -84.267500  14.91  1.38      md   6.0
# 10  2020-06-28T21:54:15.580Z  35.325167 -84.539000  17.28  1.95      md  12.0
# ...

# %%
tn_quake_df.shape
# Out:
# (777, 22)

# %%
tn_quake_df['state'] = tn_quake_df['place'].str.extract('(.*)a$')

# %%
tn_quake_df['test'] = tn_quake_df['place'].str[-9:]

# %%
tn_quake_df.tail(50)
# Out:
#                          time   latitude  longitude  depth  mag magType   nst  \
# 727  2001-08-22T21:08:18.030Z  35.584000 -84.055833  22.52  1.6      md   6.0
# 728  2001-08-11T19:53:23.690Z  36.130500 -84.587500  24.06  1.6      md   6.0
# 729  2001-06-29T15:49:03.330Z  35.015500 -84.770167  10.00  1.7      md   7.0
# 730  2001-04-23T03:38:38.290Z  35.257000 -84.135167   8.44  1.9      md   7.0
# 731  2001-03-07T17:12:24.020Z  35.530167 -84.843167  18.04  3.2     mlg  12.0
# 732  2000-09-09T23:47:28.000Z  35.150500 -85.735000   6.78  2.2      md   7.0
# 733  2000-09-08T10:10:37.890Z  35.880333 -84.314833  28.57  1.8      md   6.0
# 734  2000-07-28T20:16:39.480Z  35.677833 -84.250500  18.90  1.8      md   6.0
# 735  2000-07-11T17:44:26.310Z  35.485333 -85.177500  22.14  1.7      md   7.0
# 736  2000-06-04T05:06:47.770Z  35.559667 -84.173167  12.53  1.6      md   7.0
# 737  2000-05-15T15:05:34.260Z  35.191500 -84.882667   5.29  2.8      md  11.0
# ...
